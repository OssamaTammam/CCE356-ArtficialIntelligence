# %%
from Board import Board

# %%
def test(testLayout):
    gameBoard = Board(layout=testLayout)
    gameBoard.printState()

    gameBoard.solve()
    gameBoard.printAiPaths()

# %%
testLayout = [1, 2, 5, 3, 4, 0, 6, 7, 8]
test(testLayout)
# Out:
# Current board state:
# 1,2,5
# 3,4,0
# 6,7,8
# ------
# BFS Time: 0.00023484230041503906
# DFS Time: 0.02194690704345703
# Iterative Deepening DFS Time: 0.00017881393432617188
# A* using Manhattan Distance Time: 8.058547973632812e-05
# A* using Euclidean Distance Time: 0.00011849403381347656
# BFS:
# Number of steps taken 3
# 1,2,5
# 3,4,0
# 6,7,8
# ------
# 1,2,0
# 3,4,5
# 6,7,8
# ------
# 1,0,2
# 3,4,5
# 6,7,8
# ------
# 0,1,2
# 3,4,5
# 6,7,8
# ------
# DFS:
# Number of steps taken 431
# 1,2,5
# 3,4,0
# 6,7,8
# ------
# 1,2,5
# 3,0,4
# 6,7,8
# ------
# 1,2,5
# 0,3,4
# 6,7,8
# ------
# 1,2,5
# 6,3,4
# 0,7,8
# ------
# 1,2,5
# 6,3,4
# 7,0,8
# ------
# 1,2,5
# 6,3,4
# 7,8,0
# ------
# 1,2,5
# 6,3,0
# 7,8,4
# ------
# 1,2,5
# 6,0,3
# 7,8,4
# ------
# 1,2,5
# 0,6,3
# 7,8,4
# ------
# 1,2,5
# 7,6,3
# 0,8,4
# ------
# 1,2,5
# 7,6,3
# 8,0,4
# ------
# 1,2,5
# 7,6,3
# 8,4,0
# ------
# 1,2,5
# 7,6,0
# 8,4,3
# ------
# 1,2,5
# 7,0,6
# 8,4,3
# ------
# 1,2,5
# 0,7,6
# 8,4,3
# ------
# 1,2,5
# 8,7,6
# 0,4,3
# ------
# 1,2,5
# 8,7,6
# 4,0,3
# ------
# 1,2,5
# 8,7,6
# 4,3,0
# ------
# 1,2,5
# 8,7,0
# 4,3,6
# ------
# 1,2,5
# 8,0,7
# 4,3,6
# ------
# 1,2,5
# 0,8,7
# 4,3,6
# ------
# 1,2,5
# 4,8,7
# 0,3,6
# ------
# 1,2,5
# 4,8,7
# 3,0,6
# ------
# 1,2,5
# 4,8,7
# 3,6,0
# ------
# 1,2,5
# 4,8,0
# 3,6,7
# ------
# 1,2,5
# 4,0,8
# 3,6,7
# ------
# 1,2,5
# 0,4,8
# 3,6,7
# ------
# 1,2,5
# 3,4,8
# 0,6,7
# ------
# 1,2,5
# 3,4,8
# 6,0,7
# ------
# 1,2,5
# 3,0,8
# 6,4,7
# ------
# 1,2,5
# 3,8,0
# 6,4,7
# ------
# 1,2,5
# 3,8,7
# 6,4,0
# ------
# 1,2,5
# 3,8,7
# 6,0,4
# ------
# 1,2,5
# 3,8,7
# 0,6,4
# ------
# 1,2,5
# 0,8,7
# 3,6,4
# ------
# 1,2,5
# 8,0,7
# 3,6,4
# ------
# 1,2,5
# 8,7,0
# 3,6,4
# ------
# 1,2,5
# 8,7,4
# 3,6,0
# ------
# 1,2,5
# 8,7,4
# 3,0,6
# ------
# 1,2,5
# 8,7,4
# 0,3,6
# ------
# 1,2,5
# 0,7,4
# 8,3,6
# ------
# 1,2,5
# 7,0,4
# 8,3,6
# ------
# 1,2,5
# 7,4,0
# 8,3,6
# ------
# 1,2,5
# 7,4,6
# 8,3,0
# ------
# 1,2,5
# 7,4,6
# 8,0,3
# ------
# 1,2,5
# 7,4,6
# 0,8,3
# ------
# 1,2,5
# 0,4,6
# 7,8,3
# ------
# 1,2,5
# 4,0,6
# 7,8,3
# ------
# 1,2,5
# 4,6,0
# 7,8,3
# ------
# 1,2,5
# 4,6,3
# 7,8,0
# ------
# 1,2,5
# 4,6,3
# 7,0,8
# ------
# 1,2,5
# 4,6,3
# 0,7,8
# ------
# 1,2,5
# 0,6,3
# 4,7,8
# ------
# 1,2,5
# 6,0,3
# 4,7,8
# ------
# 1,2,5
# 6,3,0
# 4,7,8
# ------
# 1,2,5
# 6,3,8
# 4,7,0
# ------
# 1,2,5
# 6,3,8
# 4,0,7
# ------
# 1,2,5
# 6,3,8
# 0,4,7
# ------
# 1,2,5
# 0,3,8
# 6,4,7
# ------
# 0,2,5
# 1,3,8
# 6,4,7
# ------
# 2,0,5
# 1,3,8
# 6,4,7
# ------
# 2,5,0
# 1,3,8
# 6,4,7
# ------
# 2,5,8
# 1,3,0
# 6,4,7
# ------
# 2,5,8
# 1,0,3
# 6,4,7
# ------
# 2,5,8
# 0,1,3
# 6,4,7
# ------
# 2,5,8
# 6,1,3
# 0,4,7
# ------
# 2,5,8
# 6,1,3
# 4,0,7
# ------
# 2,5,8
# 6,1,3
# 4,7,0
# ------
# 2,5,8
# 6,1,0
# 4,7,3
# ------
# 2,5,8
# 6,0,1
# 4,7,3
# ------
# 2,5,8
# 0,6,1
# 4,7,3
# ------
# 2,5,8
# 4,6,1
# 0,7,3
# ------
# 2,5,8
# 4,6,1
# 7,0,3
# ------
# 2,5,8
# 4,6,1
# 7,3,0
# ------
# 2,5,8
# 4,6,0
# 7,3,1
# ------
# 2,5,8
# 4,0,6
# 7,3,1
# ------
# 2,5,8
# 0,4,6
# 7,3,1
# ------
# 2,5,8
# 7,4,6
# 0,3,1
# ------
# 2,5,8
# 7,4,6
# 3,0,1
# ------
# 2,5,8
# 7,4,6
# 3,1,0
# ------
# 2,5,8
# 7,4,0
# 3,1,6
# ------
# 2,5,8
# 7,0,4
# 3,1,6
# ------
# 2,5,8
# 0,7,4
# 3,1,6
# ------
# 2,5,8
# 3,7,4
# 0,1,6
# ------
# 2,5,8
# 3,7,4
# 1,0,6
# ------
# 2,5,8
# 3,7,4
# 1,6,0
# ------
# 2,5,8
# 3,7,0
# 1,6,4
# ------
# 2,5,8
# 3,0,7
# 1,6,4
# ------
# 2,5,8
# 0,3,7
# 1,6,4
# ------
# 2,5,8
# 1,3,7
# 0,6,4
# ------
# 2,5,8
# 1,3,7
# 6,0,4
# ------
# 2,5,8
# 1,0,7
# 6,3,4
# ------
# 2,5,8
# 1,7,0
# 6,3,4
# ------
# 2,5,8
# 1,7,4
# 6,3,0
# ------
# 2,5,8
# 1,7,4
# 6,0,3
# ------
# 2,5,8
# 1,7,4
# 0,6,3
# ------
# 2,5,8
# 0,7,4
# 1,6,3
# ------
# 2,5,8
# 7,0,4
# 1,6,3
# ------
# 2,5,8
# 7,4,0
# 1,6,3
# ------
# 2,5,8
# 7,4,3
# 1,6,0
# ------
# 2,5,8
# 7,4,3
# 1,0,6
# ------
# 2,5,8
# 7,4,3
# 0,1,6
# ------
# 2,5,8
# 0,4,3
# 7,1,6
# ------
# 2,5,8
# 4,0,3
# 7,1,6
# ------
# 2,5,8
# 4,3,0
# 7,1,6
# ------
# 2,5,8
# 4,3,6
# 7,1,0
# ------
# 2,5,8
# 4,3,6
# 7,0,1
# ------
# 2,5,8
# 4,3,6
# 0,7,1
# ------
# 2,5,8
# 0,3,6
# 4,7,1
# ------
# 2,5,8
# 3,0,6
# 4,7,1
# ------
# 2,5,8
# 3,6,0
# 4,7,1
# ------
# 2,5,8
# 3,6,1
# 4,7,0
# ------
# 2,5,8
# 3,6,1
# 4,0,7
# ------
# 2,5,8
# 3,6,1
# 0,4,7
# ------
# 2,5,8
# 0,6,1
# 3,4,7
# ------
# 2,5,8
# 6,0,1
# 3,4,7
# ------
# 2,5,8
# 6,1,0
# 3,4,7
# ------
# 2,5,8
# 6,1,7
# 3,4,0
# ------
# 2,5,8
# 6,1,7
# 3,0,4
# ------
# 2,5,8
# 6,1,7
# 0,3,4
# ------
# 2,5,8
# 0,1,7
# 6,3,4
# ------
# 0,5,8
# 2,1,7
# 6,3,4
# ------
# 5,0,8
# 2,1,7
# 6,3,4
# ------
# 5,8,0
# 2,1,7
# 6,3,4
# ------
# 5,8,7
# 2,1,0
# 6,3,4
# ------
# 5,8,7
# 2,0,1
# 6,3,4
# ------
# 5,8,7
# 0,2,1
# 6,3,4
# ------
# 5,8,7
# 6,2,1
# 0,3,4
# ------
# 5,8,7
# 6,2,1
# 3,0,4
# ------
# 5,8,7
# 6,2,1
# 3,4,0
# ------
# 5,8,7
# 6,2,0
# 3,4,1
# ------
# 5,8,7
# 6,0,2
# 3,4,1
# ------
# 5,8,7
# 0,6,2
# 3,4,1
# ------
# 5,8,7
# 3,6,2
# 0,4,1
# ------
# 5,8,7
# 3,6,2
# 4,0,1
# ------
# 5,8,7
# 3,6,2
# 4,1,0
# ------
# 5,8,7
# 3,6,0
# 4,1,2
# ------
# 5,8,7
# 3,0,6
# 4,1,2
# ------
# 5,8,7
# 0,3,6
# 4,1,2
# ------
# 5,8,7
# 4,3,6
# 0,1,2
# ------
# 5,8,7
# 4,3,6
# 1,0,2
# ------
# 5,8,7
# 4,3,6
# 1,2,0
# ------
# 5,8,7
# 4,3,0
# 1,2,6
# ------
# 5,8,7
# 4,0,3
# 1,2,6
# ------
# 5,8,7
# 0,4,3
# 1,2,6
# ------
# 5,8,7
# 1,4,3
# 0,2,6
# ------
# 5,8,7
# 1,4,3
# 2,0,6
# ------
# 5,8,7
# 1,4,3
# 2,6,0
# ------
# 5,8,7
# 1,4,0
# 2,6,3
# ------
# 5,8,7
# 1,0,4
# 2,6,3
# ------
# 5,8,7
# 0,1,4
# 2,6,3
# ------
# 5,8,7
# 2,1,4
# 0,6,3
# ------
# 5,8,7
# 2,1,4
# 6,0,3
# ------
# 5,8,7
# 2,0,4
# 6,1,3
# ------
# 5,8,7
# 2,4,0
# 6,1,3
# ------
# 5,8,7
# 2,4,3
# 6,1,0
# ------
# 5,8,7
# 2,4,3
# 6,0,1
# ------
# 5,8,7
# 2,4,3
# 0,6,1
# ------
# 5,8,7
# 0,4,3
# 2,6,1
# ------
# 5,8,7
# 4,0,3
# 2,6,1
# ------
# 5,8,7
# 4,3,0
# 2,6,1
# ------
# 5,8,7
# 4,3,1
# 2,6,0
# ------
# 5,8,7
# 4,3,1
# 2,0,6
# ------
# 5,8,7
# 4,3,1
# 0,2,6
# ------
# 5,8,7
# 0,3,1
# 4,2,6
# ------
# 5,8,7
# 3,0,1
# 4,2,6
# ------
# 5,8,7
# 3,1,0
# 4,2,6
# ------
# 5,8,7
# 3,1,6
# 4,2,0
# ------
# 5,8,7
# 3,1,6
# 4,0,2
# ------
# 5,8,7
# 3,1,6
# 0,4,2
# ------
# 5,8,7
# 0,1,6
# 3,4,2
# ------
# 5,8,7
# 1,0,6
# 3,4,2
# ------
# 5,8,7
# 1,6,0
# 3,4,2
# ------
# 5,8,7
# 1,6,2
# 3,4,0
# ------
# 5,8,7
# 1,6,2
# 3,0,4
# ------
# 5,8,7
# 1,6,2
# 0,3,4
# ------
# 5,8,7
# 0,6,2
# 1,3,4
# ------
# 5,8,7
# 6,0,2
# 1,3,4
# ------
# 5,8,7
# 6,2,0
# 1,3,4
# ------
# 5,8,7
# 6,2,4
# 1,3,0
# ------
# 5,8,7
# 6,2,4
# 1,0,3
# ------
# 5,8,7
# 6,2,4
# 0,1,3
# ------
# 5,8,7
# 0,2,4
# 6,1,3
# ------
# 0,8,7
# 5,2,4
# 6,1,3
# ------
# 8,0,7
# 5,2,4
# 6,1,3
# ------
# 8,7,0
# 5,2,4
# 6,1,3
# ------
# 8,7,4
# 5,2,0
# 6,1,3
# ------
# 8,7,4
# 5,0,2
# 6,1,3
# ------
# 8,7,4
# 0,5,2
# 6,1,3
# ------
# 8,7,4
# 6,5,2
# 0,1,3
# ------
# 8,7,4
# 6,5,2
# 1,0,3
# ------
# 8,7,4
# 6,5,2
# 1,3,0
# ------
# 8,7,4
# 6,5,0
# 1,3,2
# ------
# 8,7,4
# 6,0,5
# 1,3,2
# ------
# 8,7,4
# 0,6,5
# 1,3,2
# ------
# 8,7,4
# 1,6,5
# 0,3,2
# ------
# 8,7,4
# 1,6,5
# 3,0,2
# ------
# 8,7,4
# 1,6,5
# 3,2,0
# ------
# 8,7,4
# 1,6,0
# 3,2,5
# ------
# 8,7,4
# 1,0,6
# 3,2,5
# ------
# 8,7,4
# 0,1,6
# 3,2,5
# ------
# 8,7,4
# 3,1,6
# 0,2,5
# ------
# 8,7,4
# 3,1,6
# 2,0,5
# ------
# 8,7,4
# 3,1,6
# 2,5,0
# ------
# 8,7,4
# 3,1,0
# 2,5,6
# ------
# 8,7,4
# 3,0,1
# 2,5,6
# ------
# 8,7,4
# 0,3,1
# 2,5,6
# ------
# 8,7,4
# 2,3,1
# 0,5,6
# ------
# 8,7,4
# 2,3,1
# 5,0,6
# ------
# 8,7,4
# 2,3,1
# 5,6,0
# ------
# 8,7,4
# 2,3,0
# 5,6,1
# ------
# 8,7,4
# 2,0,3
# 5,6,1
# ------
# 8,7,4
# 0,2,3
# 5,6,1
# ------
# 8,7,4
# 5,2,3
# 0,6,1
# ------
# 8,7,4
# 5,2,3
# 6,0,1
# ------
# 8,7,4
# 5,0,3
# 6,2,1
# ------
# 8,7,4
# 5,3,0
# 6,2,1
# ------
# 8,7,4
# 5,3,1
# 6,2,0
# ------
# 8,7,4
# 5,3,1
# 6,0,2
# ------
# 8,7,4
# 5,3,1
# 0,6,2
# ------
# 8,7,4
# 0,3,1
# 5,6,2
# ------
# 8,7,4
# 3,0,1
# 5,6,2
# ------
# 8,7,4
# 3,1,0
# 5,6,2
# ------
# 8,7,4
# 3,1,2
# 5,6,0
# ------
# 8,7,4
# 3,1,2
# 5,0,6
# ------
# 8,7,4
# 3,1,2
# 0,5,6
# ------
# 8,7,4
# 0,1,2
# 3,5,6
# ------
# 8,7,4
# 1,0,2
# 3,5,6
# ------
# 8,7,4
# 1,2,0
# 3,5,6
# ------
# 8,7,4
# 1,2,6
# 3,5,0
# ------
# 8,7,4
# 1,2,6
# 3,0,5
# ------
# 8,7,4
# 1,2,6
# 0,3,5
# ------
# 8,7,4
# 0,2,6
# 1,3,5
# ------
# 8,7,4
# 2,0,6
# 1,3,5
# ------
# 8,7,4
# 2,6,0
# 1,3,5
# ------
# 8,7,4
# 2,6,5
# 1,3,0
# ------
# 8,7,4
# 2,6,5
# 1,0,3
# ------
# 8,7,4
# 2,6,5
# 0,1,3
# ------
# 8,7,4
# 0,6,5
# 2,1,3
# ------
# 8,7,4
# 6,0,5
# 2,1,3
# ------
# 8,7,4
# 6,5,0
# 2,1,3
# ------
# 8,7,4
# 6,5,3
# 2,1,0
# ------
# 8,7,4
# 6,5,3
# 2,0,1
# ------
# 8,7,4
# 6,5,3
# 0,2,1
# ------
# 8,7,4
# 0,5,3
# 6,2,1
# ------
# 0,7,4
# 8,5,3
# 6,2,1
# ------
# 7,0,4
# 8,5,3
# 6,2,1
# ------
# 7,4,0
# 8,5,3
# 6,2,1
# ------
# 7,4,3
# 8,5,0
# 6,2,1
# ------
# 7,4,3
# 8,0,5
# 6,2,1
# ------
# 7,4,3
# 0,8,5
# 6,2,1
# ------
# 7,4,3
# 6,8,5
# 0,2,1
# ------
# 7,4,3
# 6,8,5
# 2,0,1
# ------
# 7,4,3
# 6,8,5
# 2,1,0
# ------
# 7,4,3
# 6,8,0
# 2,1,5
# ------
# 7,4,3
# 6,0,8
# 2,1,5
# ------
# 7,4,3
# 0,6,8
# 2,1,5
# ------
# 7,4,3
# 2,6,8
# 0,1,5
# ------
# 7,4,3
# 2,6,8
# 1,0,5
# ------
# 7,4,3
# 2,6,8
# 1,5,0
# ------
# 7,4,3
# 2,6,0
# 1,5,8
# ------
# 7,4,3
# 2,0,6
# 1,5,8
# ------
# 7,4,3
# 0,2,6
# 1,5,8
# ------
# 7,4,3
# 1,2,6
# 0,5,8
# ------
# 7,4,3
# 1,2,6
# 5,0,8
# ------
# 7,4,3
# 1,2,6
# 5,8,0
# ------
# 7,4,3
# 1,2,0
# 5,8,6
# ------
# 7,4,3
# 1,0,2
# 5,8,6
# ------
# 7,4,3
# 0,1,2
# 5,8,6
# ------
# 7,4,3
# 5,1,2
# 0,8,6
# ------
# 7,4,3
# 5,1,2
# 8,0,6
# ------
# 7,4,3
# 5,1,2
# 8,6,0
# ------
# 7,4,3
# 5,1,0
# 8,6,2
# ------
# 7,4,3
# 5,0,1
# 8,6,2
# ------
# 7,4,3
# 0,5,1
# 8,6,2
# ------
# 7,4,3
# 8,5,1
# 0,6,2
# ------
# 7,4,3
# 8,5,1
# 6,0,2
# ------
# 7,4,3
# 8,0,1
# 6,5,2
# ------
# 7,4,3
# 8,1,0
# 6,5,2
# ------
# 7,4,3
# 8,1,2
# 6,5,0
# ------
# 7,4,3
# 8,1,2
# 6,0,5
# ------
# 7,4,3
# 8,1,2
# 0,6,5
# ------
# 7,4,3
# 0,1,2
# 8,6,5
# ------
# 7,4,3
# 1,0,2
# 8,6,5
# ------
# 7,4,3
# 1,2,0
# 8,6,5
# ------
# 7,4,3
# 1,2,5
# 8,6,0
# ------
# 7,4,3
# 1,2,5
# 8,0,6
# ------
# 7,4,3
# 1,2,5
# 0,8,6
# ------
# 7,4,3
# 0,2,5
# 1,8,6
# ------
# 7,4,3
# 2,0,5
# 1,8,6
# ------
# 7,4,3
# 2,5,0
# 1,8,6
# ------
# 7,4,3
# 2,5,6
# 1,8,0
# ------
# 7,4,3
# 2,5,6
# 1,0,8
# ------
# 7,4,3
# 2,5,6
# 0,1,8
# ------
# 7,4,3
# 0,5,6
# 2,1,8
# ------
# 7,4,3
# 5,0,6
# 2,1,8
# ------
# 7,4,3
# 5,6,0
# 2,1,8
# ------
# 7,4,3
# 5,6,8
# 2,1,0
# ------
# 7,4,3
# 5,6,8
# 2,0,1
# ------
# 7,4,3
# 5,6,8
# 0,2,1
# ------
# 7,4,3
# 0,6,8
# 5,2,1
# ------
# 7,4,3
# 6,0,8
# 5,2,1
# ------
# 7,4,3
# 6,8,0
# 5,2,1
# ------
# 7,4,3
# 6,8,1
# 5,2,0
# ------
# 7,4,3
# 6,8,1
# 5,0,2
# ------
# 7,4,3
# 6,8,1
# 0,5,2
# ------
# 7,4,3
# 0,8,1
# 6,5,2
# ------
# 0,4,3
# 7,8,1
# 6,5,2
# ------
# 4,0,3
# 7,8,1
# 6,5,2
# ------
# 4,3,0
# 7,8,1
# 6,5,2
# ------
# 4,3,1
# 7,8,0
# 6,5,2
# ------
# 4,3,1
# 7,0,8
# 6,5,2
# ------
# 4,3,1
# 0,7,8
# 6,5,2
# ------
# 4,3,1
# 6,7,8
# 0,5,2
# ------
# 4,3,1
# 6,7,8
# 5,0,2
# ------
# 4,3,1
# 6,7,8
# 5,2,0
# ------
# 4,3,1
# 6,7,0
# 5,2,8
# ------
# 4,3,1
# 6,0,7
# 5,2,8
# ------
# 4,3,1
# 0,6,7
# 5,2,8
# ------
# 4,3,1
# 5,6,7
# 0,2,8
# ------
# 4,3,1
# 5,6,7
# 2,0,8
# ------
# 4,3,1
# 5,6,7
# 2,8,0
# ------
# 4,3,1
# 5,6,0
# 2,8,7
# ------
# 4,3,1
# 5,0,6
# 2,8,7
# ------
# 4,3,1
# 0,5,6
# 2,8,7
# ------
# 4,3,1
# 2,5,6
# 0,8,7
# ------
# 4,3,1
# 2,5,6
# 8,0,7
# ------
# 4,3,1
# 2,5,6
# 8,7,0
# ------
# 4,3,1
# 2,5,0
# 8,7,6
# ------
# 4,3,1
# 2,0,5
# 8,7,6
# ------
# 4,3,1
# 0,2,5
# 8,7,6
# ------
# 4,3,1
# 8,2,5
# 0,7,6
# ------
# 4,3,1
# 8,2,5
# 7,0,6
# ------
# 4,3,1
# 8,2,5
# 7,6,0
# ------
# 4,3,1
# 8,2,0
# 7,6,5
# ------
# 4,3,1
# 8,0,2
# 7,6,5
# ------
# 4,3,1
# 0,8,2
# 7,6,5
# ------
# 4,3,1
# 7,8,2
# 0,6,5
# ------
# 4,3,1
# 7,8,2
# 6,0,5
# ------
# 4,3,1
# 7,0,2
# 6,8,5
# ------
# 4,3,1
# 7,2,0
# 6,8,5
# ------
# 4,3,1
# 7,2,5
# 6,8,0
# ------
# 4,3,1
# 7,2,5
# 6,0,8
# ------
# 4,3,1
# 7,2,5
# 0,6,8
# ------
# 4,3,1
# 0,2,5
# 7,6,8
# ------
# 4,3,1
# 2,0,5
# 7,6,8
# ------
# 4,3,1
# 2,5,0
# 7,6,8
# ------
# 4,3,1
# 2,5,8
# 7,6,0
# ------
# 4,3,1
# 2,5,8
# 7,0,6
# ------
# 4,3,1
# 2,5,8
# 0,7,6
# ------
# 4,3,1
# 0,5,8
# 2,7,6
# ------
# 4,3,1
# 5,0,8
# 2,7,6
# ------
# 4,3,1
# 5,8,0
# 2,7,6
# ------
# 4,3,1
# 5,8,6
# 2,7,0
# ------
# 4,3,1
# 5,8,6
# 2,0,7
# ------
# 4,3,1
# 5,8,6
# 0,2,7
# ------
# 4,3,1
# 0,8,6
# 5,2,7
# ------
# 4,3,1
# 8,0,6
# 5,2,7
# ------
# 4,3,1
# 8,6,0
# 5,2,7
# ------
# 4,3,1
# 8,6,7
# 5,2,0
# ------
# 4,3,1
# 8,6,7
# 5,0,2
# ------
# 4,3,1
# 8,6,7
# 0,5,2
# ------
# 4,3,1
# 0,6,7
# 8,5,2
# ------
# 4,3,1
# 6,0,7
# 8,5,2
# ------
# 4,3,1
# 6,7,0
# 8,5,2
# ------
# 4,3,1
# 6,7,2
# 8,5,0
# ------
# 4,3,1
# 6,7,2
# 8,0,5
# ------
# 4,3,1
# 6,7,2
# 0,8,5
# ------
# 4,3,1
# 0,7,2
# 6,8,5
# ------
# 0,3,1
# 4,7,2
# 6,8,5
# ------
# 3,0,1
# 4,7,2
# 6,8,5
# ------
# 3,1,0
# 4,7,2
# 6,8,5
# ------
# 3,1,2
# 4,7,0
# 6,8,5
# ------
# 3,1,2
# 4,0,7
# 6,8,5
# ------
# 3,1,2
# 0,4,7
# 6,8,5
# ------
# 3,1,2
# 6,4,7
# 0,8,5
# ------
# 3,1,2
# 6,4,7
# 8,0,5
# ------
# 3,1,2
# 6,4,7
# 8,5,0
# ------
# 3,1,2
# 6,4,0
# 8,5,7
# ------
# 3,1,2
# 6,0,4
# 8,5,7
# ------
# 3,1,2
# 0,6,4
# 8,5,7
# ------
# 3,1,2
# 8,6,4
# 0,5,7
# ------
# 3,1,2
# 8,6,4
# 5,0,7
# ------
# 3,1,2
# 8,6,4
# 5,7,0
# ------
# 3,1,2
# 8,6,0
# 5,7,4
# ------
# 3,1,2
# 8,0,6
# 5,7,4
# ------
# 3,1,2
# 0,8,6
# 5,7,4
# ------
# 3,1,2
# 5,8,6
# 0,7,4
# ------
# 3,1,2
# 5,8,6
# 7,0,4
# ------
# 3,1,2
# 5,8,6
# 7,4,0
# ------
# 3,1,2
# 5,8,0
# 7,4,6
# ------
# 3,1,2
# 5,0,8
# 7,4,6
# ------
# 3,1,2
# 0,5,8
# 7,4,6
# ------
# 3,1,2
# 7,5,8
# 0,4,6
# ------
# 3,1,2
# 7,5,8
# 4,0,6
# ------
# 3,1,2
# 7,5,8
# 4,6,0
# ------
# 3,1,2
# 7,5,0
# 4,6,8
# ------
# 3,1,2
# 7,0,5
# 4,6,8
# ------
# 3,1,2
# 0,7,5
# 4,6,8
# ------
# 3,1,2
# 4,7,5
# 0,6,8
# ------
# 3,1,2
# 4,7,5
# 6,0,8
# ------
# 3,1,2
# 4,0,5
# 6,7,8
# ------
# 3,1,2
# 4,5,0
# 6,7,8
# ------
# 3,1,2
# 4,5,8
# 6,7,0
# ------
# 3,1,2
# 4,5,8
# 6,0,7
# ------
# 3,1,2
# 4,5,8
# 0,6,7
# ------
# 3,1,2
# 0,5,8
# 4,6,7
# ------
# 3,1,2
# 5,0,8
# 4,6,7
# ------
# 3,1,2
# 5,8,0
# 4,6,7
# ------
# 3,1,2
# 5,8,7
# 4,6,0
# ------
# 3,1,2
# 5,8,7
# 4,0,6
# ------
# 3,1,2
# 5,8,7
# 0,4,6
# ------
# 3,1,2
# 0,8,7
# 5,4,6
# ------
# 3,1,2
# 8,0,7
# 5,4,6
# ------
# 3,1,2
# 8,7,0
# 5,4,6
# ------
# 3,1,2
# 8,7,6
# 5,4,0
# ------
# 3,1,2
# 8,7,6
# 5,0,4
# ------
# 3,1,2
# 8,7,6
# 0,5,4
# ------
# 3,1,2
# 0,7,6
# 8,5,4
# ------
# 3,1,2
# 7,0,6
# 8,5,4
# ------
# 3,1,2
# 7,6,0
# 8,5,4
# ------
# 3,1,2
# 7,6,4
# 8,5,0
# ------
# 3,1,2
# 7,6,4
# 8,0,5
# ------
# 3,1,2
# 7,6,4
# 0,8,5
# ------
# 3,1,2
# 0,6,4
# 7,8,5
# ------
# 3,1,2
# 6,0,4
# 7,8,5
# ------
# 3,1,2
# 6,4,0
# 7,8,5
# ------
# 3,1,2
# 6,4,5
# 7,8,0
# ------
# 3,1,2
# 6,4,5
# 7,0,8
# ------
# 3,1,2
# 6,4,5
# 0,7,8
# ------
# 3,1,2
# 0,4,5
# 6,7,8
# ------
# 0,1,2
# 3,4,5
# 6,7,8
# ------
# Iterative Deepening DFS:
# Number of steps taken 3
# 1,2,5
# 3,4,0
# 6,7,8
# ------
# 1,2,0
# 3,4,5
# 6,7,8
# ------
# 1,0,2
# 3,4,5
# 6,7,8
# ------
# 0,1,2
# 3,4,5
# 6,7,8
# ------
# AStar Manhattan:
# Number of steps taken 3
# 1,2,5
# 3,4,0
# 6,7,8
# ------
# 1,2,0
# 3,4,5
# 6,7,8
# ------
# 1,0,2
# 3,4,5
# 6,7,8
# ------
# 0,1,2
# 3,4,5
# 6,7,8
# ------
# AStar Euclidean:
# Number of steps taken 3
# 1,2,5
# 3,4,0
# 6,7,8
# ------
# 1,2,0
# 3,4,5
# 6,7,8
# ------
# 1,0,2
# 3,4,5
# 6,7,8
# ------
# 0,1,2
# 3,4,5
# 6,7,8
# ------

# %%
testLayout = [2, 8, 0, 1, 5, 3, 6, 4, 7]
test(testLayout)
# Out:
# Current board state:
# 2,8,0
# 1,5,3
# 6,4,7
# ------
# BFS Time: 1.4483506679534912
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 testLayout = [2, 8, 0, 1, 5, 3, 6, 4, 7]
# ----> 2 test(testLayout)
#
# Cell In[3], line 5, in test(testLayout)
#       2 gameBoard = Board(layout=testLayout)
#       3 gameBoard.printState()
# ----> 5 gameBoard.solve()
#       6 gameBoard.printAiPaths()
#
# File ~/programming/uni/term_8/ai/assignment_1/Board.py:16, in Board.solve(self)
#      15 def solve(self) -> None:
# ---> 16     self.ai.solve()
#
# File ~/programming/uni/term_8/ai/assignment_1/AI.py:28, in AI.solve(self)
#      25 print(f"BFS Time: {time() - startTime}")
#      27 startTime = time()
# ---> 28 self.dfsPath = self.DFS()
#      29 print(f"DFS Time: {time() - startTime}")
#      31 startTime = time()
#
# File ~/programming/uni/term_8/ai/assignment_1/AI.py:76, in AI.DFS(self)
#      74 visited.add(currState)
#      75 for neighborState in currState.getNeighbors():
# ---> 76     if neighborState not in visited and neighborState not in stack:
#      77         neighbor = (neighborState, currPath + [neighborState])
#      78         stack.append(neighbor)
#
# File ~/programming/uni/term_8/ai/assignment_1/BoardState.py:23, in BoardState.__eq__(self, other)
#      22 def __eq__(self, other) -> bool:
# ---> 23     if not isinstance(other, BoardState):
#      24         return False
#      25     return self.layout == other.layout
#
# KeyboardInterrupt:

# %%
testLayout = [7, 2, 4, 5, 0, 6, 8, 3, 1]
test(testLayout)
# Out:
# Current board state:
# 7,2,4
# 5,0,6
# 8,3,1
# ------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 testLayout = [7, 2, 4, 5, 0, 6, 8, 3, 1]
# ----> 2 test(testLayout)
#
# Cell In[3], line 5, in test(testLayout)
#       2 gameBoard = Board(layout=testLayout)
#       3 gameBoard.printState()
# ----> 5 gameBoard.solve()
#       6 gameBoard.printAiPaths()
#
# File ~/programming/uni/term_8/ai/assignment_1/Board.py:16, in Board.solve(self)
#      15 def solve(self) -> None:
# ---> 16     self.ai.solve()
#
# File ~/programming/uni/term_8/ai/assignment_1/AI.py:24, in AI.solve(self)
#      22 def solve(self):
#      23     startTime = time()
# ---> 24     self.bfsPath = self.BFS()
#      25     print(f"BFS Time: {time() - startTime}")
#      27     startTime = time()
#
# File ~/programming/uni/term_8/ai/assignment_1/AI.py:57, in AI.BFS(self)
#      55 visited.add(currState)
#      56 for neighborState in currState.getNeighbors():
# ---> 57     if neighborState not in visited and neighborState not in queue:
#      58         neighbor = (neighborState, currPath + [neighborState])
#      59         queue.append(neighbor)
#
# File ~/programming/uni/term_8/ai/assignment_1/BoardState.py:22, in BoardState.__eq__(self, other)
#      19 def __lt__(self, other) -> bool:
#      20     return self.cost <= other.cost
# ---> 22 def __eq__(self, other) -> bool:
#      23     if not isinstance(other, BoardState):
#      24         return False
#
# KeyboardInterrupt:
